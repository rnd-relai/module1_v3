# %%
import pandas as pd

# %%
dataAfterFE= pd.read_csv('01_egr_af_ANNKM.csv')

# %%
dataAfterFE.shape
# Out:
# (109845, 236)

# %%
dataAfterFE['vin'].value_counts()
# Out:
# MB1A3EHD6JPBE3633    415
# MB1A3EHD4JPBE3761    401
# MB1A3EHD9JPCD8591    355
# MB1A3EHD1JABJ2636    353
# MB1KACHD4KPJG5725    343
#                     ...
# MB1TLKHD6KPFJ7056      1
# MB1UPDHD0JPFC7113      1
# MB1UPDHD6JPED2250      1
# MB1KACHD2JPCD7801      1
# MB1G3DHD0JPDD4419      1
# Name: vin, Length: 1122, dtype: int64

# %%
pd.set_option('display.max_rows', 150)
dataAfterFE[dataAfterFE['vin'] == 'MB1A3EHD5JADJ1088'].head(120)
# Out:
#       Power_mean  Power_median  Power_variance  Power_max  Power_min  \
# 5696    0.350876      0.240476        0.193639   0.430645   0.929644
# 5697    0.349178      0.236384        0.182807   0.423650   0.930740
# 5698    0.324967      0.207951        0.161178   0.385270   0.904880
# 5699    0.318781      0.196277        0.159603   0.375636   0.905837
# 5700    0.320463      0.198624        0.154067   0.376225   0.903369
# 5701    0.331860      0.204510        0.149943   0.376587   0.913003
# 5702    0.342610      0.213206        0.158810   0.388345   0.931111
# 5703    0.347068      0.214004        0.152932   0.381880   0.937126
# 5704    0.329001      0.207630        0.151260   0.384040   0.911979
# 5705    0.340768      0.225025        0.167795   0.404142   0.924706
# 5706    0.342441      0.230615        0.181533   0.411693   0.924235
# 5707    0.334892      0.224697        0.171203   0.398437   0.917631
# 5708    0.337754      0.222280        0.162270   0.396920   0.919247
# 5709    0.349274      0.216812        0.159691   0.383044   0.925736
# 5710    0.337407      0.212245        0.176540   0.415862   0.921090
# 5711    0.339195      0.215779        0.173000   0.418215   0.917025
# 5712    0.335617      0.216135        0.162149   0.399382   0.905755
# 5713    0.334513      0.213695        0.162424   0.393386   0.912114
# 5714    0.329812      0.216251        0.165156   0.396652   0.909729
# 5715    0.335250      0.221560        0.173861   0.402467   0.915108
# 5716    0.356953      0.237085        0.177330   0.422018   0.938914
# 5717    0.345826      0.229425        0.170197   0.418007   0.929476
# 5718    0.344464      0.226585        0.170053   0.416150   0.926957
# 5719    0.364318      0.236306        0.175670   0.410886   0.940783
# 5720    0.352938      0.225031        0.180530   0.414477   0.940385
# 5721    0.354345      0.227481        0.178299   0.413832   0.941487
# 5722    0.347531      0.228986        0.181051   0.418775   0.916236
# 5723    0.347797      0.231967        0.180096   0.415273   0.915492
# 5724    0.349533      0.224098        0.204017   0.428064   0.925230
# 5725    0.353367      0.230357        0.215485   0.447660   0.928272
# 5726    0.355309      0.236954        0.195151   0.443476   0.923320
# 5727    0.369690      0.242628        0.188179   0.418104   0.938077
# 5728    0.348532      0.230857        0.183864   0.418497   0.928063
# 5729    0.337611      0.225407        0.178422   0.409750   0.926006
# 5730    0.332500      0.215694        0.169461   0.400723   0.903981
# 5731    0.347005      0.227305        0.174270   0.414166   0.913679
# 5732    0.320256      0.213651        0.175665   0.407472   0.915200
# 5733    0.316596      0.207364        0.176394   0.407061   0.913391
# 5704                  0
# 5705                  0
# 5706                  0
# 5707                  0
# 5708                  0
# 5709                  0
# 5710                  0
# 5711                  0
# 5712                  0
# 5713                  0
# 5714                  0
# 5715                  0
# 5716                  0
# 5717                  0
# 5718                  0
# 5719                  0
# 5720                  0
# 5721                  0
# 5722                  0
# 5723                  0
# 5724                  0
# 5725                  0
# 5726                  0
# 5727                  0
# 5728                  0
# 5729                  0
# 5730                  0
# 5731                  0
# 5732                  0
# 5733                  0
# 5734                  0
# 5735                  0
# 5736                  0
# 5737                  0
# 5738                  0
# 5739                  0
# 5740                  0
# 5741                  0
# 5742                  0
# 5743                  0
# 5744                  0
# 5745                  0
# 5746                  0
# 5747                  0
# 5748                  0
# 5749                  0
# 5750                  0
# 5751                  0
# 5752                  0
# 5753                  0
# 5754                  0
# 5755                  0
# 5756                  0
# 5757                  0
# 5758                  0
# 5759                  0
# 5760                  0
# 5761                  0
# 5762                  0
# 5763                  0
# 5764                  0
# 5765                  0
# 5766                  0
# 5767                  0
# 5768                  0
# 5769                  0
# 5770                  0
# 5771                  0
# 5772                  0
# 5773                  0
# 5774                  0
# 5775                  0
# 5776                  0
# 5777                  0
# 5778                  0
# 5779                  0
# 5780                  0
# 5781                  0
# 5782                  0
# 5783                  0
# 5784                  0
# 5785                  0
# 5786                  0
# 5787                  0
# 5788                  0
# 5789                  0
# 5790                  0
# 5791                  0
# 5792                  0
# 5793                  0
# 5794                  0
# 5795                  0
# 5796                  0
# 5797                  0
# 5798                  0
# 5799                  0
# 5800                  0
# 5801                  0
# 5802                  0
# 5803                  0
# 5804                  0
# 5805                  0
# 5806                  0
# 5807                  0
# 5808                  0
# 5809                  0
# 5810                  0
# 5811                  0
# 5812                  0
# 5813                  0
# 5814                  0
# 5815                  0
#
# [120 rows x 236 columns]

# %%
list(dataAfterFE.columns)
# Out:
# ['Power_mean',
#  'Power_median',
#  'Power_variance',
#  'Power_max',
#  'Power_min',
#  'Power_max-min',
#  'Power_kurtosis',
#  'Power_skewness',
#  'engine_speed_mean',
#  'engine_speed_median',
#  'engine_speed_variance',
#  'engine_speed_max',
#  'engine_speed_min',
#  'engine_speed_max-min',
#  'engine_speed_kurtosis',
#  'engine_speed_skewness',
#  'VEHICAL_BATTERY_POTENTIAL_mean',
#  'VEHICAL_BATTERY_POTENTIAL_median',
#  'VEHICAL_BATTERY_POTENTIAL_variance',
#  'VEHICAL_BATTERY_POTENTIAL_max',
#  'VEHICAL_BATTERY_POTENTIAL_min',
#  'VEHICAL_BATTERY_POTENTIAL_max-min',
#  'VEHICAL_BATTERY_POTENTIAL_kurtosis',
#  'VEHICAL_BATTERY_POTENTIAL_skewness',
#  'FUEL_CONSUM_mean',
#  'FUEL_CONSUM_median',
#  'FUEL_CONSUM_variance',
#  'FUEL_CONSUM_max',
#  'FUEL_CONSUM_min',
#  'FUEL_CONSUM_max-min',
#  'FUEL_CONSUM_kurtosis',
#  'FUEL_CONSUM_skewness',
#  'THROTTLE_POS_mean',
#  'THROTTLE_POS_median',
#  'THROTTLE_POS_variance',
#  'THROTTLE_POS_max',
#  'THROTTLE_POS_min',
#  'THROTTLE_POS_max-min',
#  'THROTTLE_POS_kurtosis',
#  'THROTTLE_POS_skewness',
#  'ACTUAL_ENGINE_TORQUE_mean',
#  'ACTUAL_ENGINE_TORQUE_median',
#  'ACTUAL_ENGINE_TORQUE_variance',
#  'ACTUAL_ENGINE_TORQUE_max',
#  'ACTUAL_ENGINE_TORQUE_min',
#  'ACTUAL_ENGINE_TORQUE_max-min',
#  'ACTUAL_ENGINE_TORQUE_kurtosis',
#  'ACTUAL_ENGINE_TORQUE_skewness',
#  'ENGINE_OIL_TEMP_mean',
#  'ENGINE_OIL_TEMP_median',
#  'ENGINE_OIL_TEMP_variance',
#  'ENGINE_OIL_TEMP_max',
#  'ENGINE_OIL_TEMP_min',
#  'ENGINE_OIL_TEMP_max-min',
#  'ENGINE_OIL_TEMP_kurtosis',
#  'ENGINE_OIL_TEMP_skewness',
#  'ENGINE_INTAKE_M_PRESSURE_mean',
#  'ENGINE_INTAKE_M_PRESSURE_median',
#  'ENGINE_INTAKE_M_PRESSURE_variance',
#  'ENGINE_INTAKE_M_PRESSURE_max',
#  'ENGINE_INTAKE_M_PRESSURE_min',
#  'ENGINE_INTAKE_M_PRESSURE_max-min',
#  'ENGINE_INTAKE_M_PRESSURE_kurtosis',
#  'ENGINE_INTAKE_M_PRESSURE_skewness',
#  'ENGINE_INTAKE_M_TEMPERATURE_mean',
#  'ENGINE_INTAKE_M_TEMPERATURE_median',
#  'ENGINE_INTAKE_M_TEMPERATURE_variance',
#  'ENGINE_INTAKE_M_TEMPERATURE_max',
#  'ENGINE_INTAKE_M_TEMPERATURE_min',
#  'ENGINE_INTAKE_M_TEMPERATURE_max-min',
#  'ENGINE_INTAKE_M_TEMPERATURE_kurtosis',
#  'ENGINE_INTAKE_M_TEMPERATURE_skewness',
#  'ENGINE_AIR_INLET_PRESSURE_mean',
#  'ENGINE_AIR_INLET_PRESSURE_median',
#  'ENGINE_AIR_INLET_PRESSURE_variance',
#  'ENGINE_AIR_INLET_PRESSURE_max',
#  'ENGINE_AIR_INLET_PRESSURE_min',
#  'ENGINE_AIR_INLET_PRESSURE_max-min',
#  'ENGINE_AIR_INLET_PRESSURE_kurtosis',
#  'ENGINE_AIR_INLET_PRESSURE_skewness',
#  'AMBIENT_AIR_TEMP_mean',
#  'AMBIENT_AIR_TEMP_median',
#  'AMBIENT_AIR_TEMP_variance',
#  'AMBIENT_AIR_TEMP_max',
#  'AMBIENT_AIR_TEMP_min',
#  'AMBIENT_AIR_TEMP_max-min',
#  'AMBIENT_AIR_TEMP_kurtosis',
#  'AMBIENT_AIR_TEMP_skewness',
#  'ENGINE_FUEL_TEMP_1_mean',
#  'ENGINE_FUEL_TEMP_1_median',
#  'ENGINE_FUEL_TEMP_1_variance',
#  'ENGINE_FUEL_TEMP_1_max',
#  'ENGINE_FUEL_TEMP_1_min',
#  'ENGINE_FUEL_TEMP_1_max-min',
#  'ENGINE_FUEL_TEMP_1_kurtosis',
#  'ENGINE_FUEL_TEMP_1_skewness',
#  'BAT_CHARGING_CURRENT_mean',
#  'BAT_CHARGING_CURRENT_median',
#  'BAT_CHARGING_CURRENT_variance',
#  'BAT_CHARGING_CURRENT_max',
#  'BAT_CHARGING_CURRENT_min',
#  'BAT_CHARGING_CURRENT_max-min',
#  'BAT_CHARGING_CURRENT_kurtosis',
#  'BAT_CHARGING_CURRENT_skewness',
#  'ENGINE_OIL_PRESSURE_mean',
#  'ENGINE_OIL_PRESSURE_median',
#  'ENGINE_OIL_PRESSURE_variance',
#  'ENGINE_OIL_PRESSURE_max',
#  'ENGINE_OIL_PRESSURE_min',
#  'ENGINE_OIL_PRESSURE_max-min',
#  'ENGINE_OIL_PRESSURE_kurtosis',
#  'ENGINE_OIL_PRESSURE_skewness',
#  'AIR_PRESSURE_1_mean',
#  'AIR_PRESSURE_1_median',
#  'AIR_PRESSURE_1_variance',
#  'AIR_PRESSURE_1_max',
#  'AIR_PRESSURE_1_min',
#  'AIR_PRESSURE_1_max-min',
#  'AIR_PRESSURE_1_kurtosis',
#  'AIR_PRESSURE_1_skewness',
#  'AIR_PRESSURE_2_mean',
#  'AIR_PRESSURE_2_median',
#  'AIR_PRESSURE_2_variance',
#  'AIR_PRESSURE_2_max',
#  'AIR_PRESSURE_2_min',
#  'AIR_PRESSURE_2_max-min',
#  'AIR_PRESSURE_2_kurtosis',
#  'AIR_PRESSURE_2_skewness',
#  'AIR_PRESSURE_DIGITAL_mean',
#  'AIR_PRESSURE_DIGITAL_median',
#  'AIR_PRESSURE_DIGITAL_variance',
#  'AIR_PRESSURE_DIGITAL_max',
#  'AIR_PRESSURE_DIGITAL_min',
#  'AIR_PRESSURE_DIGITAL_max-min',
#  'AIR_PRESSURE_DIGITAL_kurtosis',
#  'AIR_PRESSURE_DIGITAL_skewness',
#  'ENG_OIL_DIGITAL_mean',
#  'ENG_OIL_DIGITAL_median',
#  'ENG_OIL_DIGITAL_variance',
#  'ENG_OIL_DIGITAL_max',
#  'ENG_OIL_DIGITAL_min',
#  'ENG_OIL_DIGITAL_max-min',
#  'ENG_OIL_DIGITAL_kurtosis',
#  'ENG_OIL_DIGITAL_skewness',
#  'eng_coolant_temp_mean',
#  'eng_coolant_temp_median',
#  'eng_coolant_temp_variance',
#  'eng_coolant_temp_max',
#  'eng_coolant_temp_min',
#  'eng_coolant_temp_max-min',
#  'eng_coolant_temp_kurtosis',
#  'eng_coolant_temp_skewness',
#  'distance_idle%',
#  'distance_overrun%',
#  'distance_decel%',
#  'distance_accel%',
#  'time_idle%',
#  'time_overrun%',
#  'time_decel%',
#  'time_accel%',
#  '5409',
#  '535',
#  '525569',
#  '6912',
#  '5888',
#  '6144',
#  '131363',
#  '131619',
#  '8501',
#  '5688',
#  '262288',
#  '131895',
#  '4386',
#  '69888',
#  '5169',
#  '4356',
#  '4406',
#  '131906',
#  '267048',
#  'total',
#  '22',
#  '4377',
#  '408',
#  '267012',
#  '4390',
#  '9502',
#  '4369',
#  '1315',
#  '4371',
#  '65939',
#  '4613',
#  '1028',
#  '1025',
#  '1030',
#  '1156',
#  '4614',
#  '66104',
#  '1159',
#  '65816',
#  '275',
#  '1344',
#  '5376',
#  '1316',
#  '4374',
#  '66370',
#  '267024',
#  '537',
#  '663',
#  '9501',
#  '70434',
#  '267042',
#  '257',
#  '295',
#  '6657',
#  '131352',
#  '5120',
#  '6400',
#  '66359',
#  '1026',
#  '4626',
#  '1314',
#  '267060',
#  '4385',
#  '5696',
#  '4612',
#  '533',
#  '5634',
#  '4375',
#  '5159',
#  '74065',
#  'r_error',
#  'ANN_EGR_N',
#  'ANN_AIR_FILTER_N',
#  'vin',
#  'ANN_EGR_KM',
#  'ANN_AIR_FILTER_KM']

# %%
col_list = ['Power_mean',
 'Power_median',
 'Power_variance',
 'Power_max',
 'Power_min',
 'Power_max-min',

 'Power_kurtosis',
 'Power_skewness',
 'engine_speed_mean',
 'engine_speed_median',
 'engine_speed_variance',
 'engine_speed_max',
 'engine_speed_min',
 'engine_speed_max-min',
 
 'engine_speed_kurtosis',
 'engine_speed_skewness',
 'VEHICAL_BATTERY_POTENTIAL_mean',
 'VEHICAL_BATTERY_POTENTIAL_median',
 'VEHICAL_BATTERY_POTENTIAL_variance',
 'VEHICAL_BATTERY_POTENTIAL_max',
 'VEHICAL_BATTERY_POTENTIAL_min',
 'VEHICAL_BATTERY_POTENTIAL_max-min',

 'VEHICAL_BATTERY_POTENTIAL_kurtosis',
 'VEHICAL_BATTERY_POTENTIAL_skewness',
 'FUEL_CONSUM_mean',
 'FUEL_CONSUM_median',
 'FUEL_CONSUM_variance',
 'FUEL_CONSUM_max',
 'FUEL_CONSUM_min',
 'FUEL_CONSUM_max-min',

 'FUEL_CONSUM_kurtosis',
 'FUEL_CONSUM_skewness',
 'THROTTLE_POS_mean',
 'THROTTLE_POS_median',
 'THROTTLE_POS_variance',
 'THROTTLE_POS_max',
 'THROTTLE_POS_min',
 'THROTTLE_POS_max-min',

 'THROTTLE_POS_kurtosis',
 'THROTTLE_POS_skewness',
 'ACTUAL_ENGINE_TORQUE_mean',
 'ACTUAL_ENGINE_TORQUE_median',
 'ACTUAL_ENGINE_TORQUE_variance',
 'ACTUAL_ENGINE_TORQUE_max',
 'ACTUAL_ENGINE_TORQUE_min',
 'ACTUAL_ENGINE_TORQUE_max-min',

 'ACTUAL_ENGINE_TORQUE_kurtosis',
 'ACTUAL_ENGINE_TORQUE_skewness',
 'ENGINE_OIL_TEMP_mean',
 'ENGINE_OIL_TEMP_median',
 'ENGINE_OIL_TEMP_variance',
 'ENGINE_OIL_TEMP_max',
 'ENGINE_OIL_TEMP_min',
 'ENGINE_OIL_TEMP_max-min',

 'ENGINE_OIL_TEMP_kurtosis',
 'ENGINE_OIL_TEMP_skewness',
 'ENGINE_INTAKE_M_PRESSURE_mean',
 'ENGINE_INTAKE_M_PRESSURE_median',
 'ENGINE_INTAKE_M_PRESSURE_variance',
 'ENGINE_INTAKE_M_PRESSURE_max',
 'ENGINE_INTAKE_M_PRESSURE_min',
 'ENGINE_INTAKE_M_PRESSURE_max-min',

 'ENGINE_INTAKE_M_PRESSURE_kurtosis',
 'ENGINE_INTAKE_M_PRESSURE_skewness',
 'ENGINE_INTAKE_M_TEMPERATURE_mean',
 'ENGINE_INTAKE_M_TEMPERATURE_median',
 'ENGINE_INTAKE_M_TEMPERATURE_variance',
 'ENGINE_INTAKE_M_TEMPERATURE_max',
 'ENGINE_INTAKE_M_TEMPERATURE_min',
 'ENGINE_INTAKE_M_TEMPERATURE_max-min',

 'ENGINE_INTAKE_M_TEMPERATURE_kurtosis',
 'ENGINE_INTAKE_M_TEMPERATURE_skewness',
 'ENGINE_AIR_INLET_PRESSURE_mean',
 'ENGINE_AIR_INLET_PRESSURE_median',
 'ENGINE_AIR_INLET_PRESSURE_variance',
 'ENGINE_AIR_INLET_PRESSURE_max',
 'ENGINE_AIR_INLET_PRESSURE_min',
 'ENGINE_AIR_INLET_PRESSURE_max-min',

 'ENGINE_AIR_INLET_PRESSURE_kurtosis',
 'ENGINE_AIR_INLET_PRESSURE_skewness',
 'AMBIENT_AIR_TEMP_mean',
 'AMBIENT_AIR_TEMP_median',
 'AMBIENT_AIR_TEMP_variance',
 'AMBIENT_AIR_TEMP_max',
 'AMBIENT_AIR_TEMP_min',
 'AMBIENT_AIR_TEMP_max-min',
 
 'AMBIENT_AIR_TEMP_kurtosis',
 'AMBIENT_AIR_TEMP_skewness',
 'ENGINE_FUEL_TEMP_1_mean',
 'ENGINE_FUEL_TEMP_1_median',
 'ENGINE_FUEL_TEMP_1_variance',
 'ENGINE_FUEL_TEMP_1_max',
 'ENGINE_FUEL_TEMP_1_min',
 'ENGINE_FUEL_TEMP_1_max-min',

 'ENGINE_FUEL_TEMP_1_kurtosis',
 'ENGINE_FUEL_TEMP_1_skewness',
 'BAT_CHARGING_CURRENT_mean',
 'BAT_CHARGING_CURRENT_median',
 'BAT_CHARGING_CURRENT_variance',
 'BAT_CHARGING_CURRENT_max',
 'BAT_CHARGING_CURRENT_min',
 'BAT_CHARGING_CURRENT_max-min',

 'BAT_CHARGING_CURRENT_kurtosis',
 'BAT_CHARGING_CURRENT_skewness',
 'ENGINE_OIL_PRESSURE_mean',
 'ENGINE_OIL_PRESSURE_median',
 'ENGINE_OIL_PRESSURE_variance',
 'ENGINE_OIL_PRESSURE_max',
 'ENGINE_OIL_PRESSURE_min',
 'ENGINE_OIL_PRESSURE_max-min',
 
 'ENGINE_OIL_PRESSURE_kurtosis',
 'ENGINE_OIL_PRESSURE_skewness',
 'AIR_PRESSURE_1_mean',
 'AIR_PRESSURE_1_median',
 'AIR_PRESSURE_1_variance',
 'AIR_PRESSURE_1_max',
 'AIR_PRESSURE_1_min',
 'AIR_PRESSURE_1_max-min',

 'AIR_PRESSURE_1_kurtosis',
 'AIR_PRESSURE_1_skewness',
 'AIR_PRESSURE_2_mean',
 'AIR_PRESSURE_2_median',
 'AIR_PRESSURE_2_variance',
 'AIR_PRESSURE_2_max',
 'AIR_PRESSURE_2_min',
 'AIR_PRESSURE_2_max-min',

 'AIR_PRESSURE_2_kurtosis',
 'AIR_PRESSURE_2_skewness',
 'AIR_PRESSURE_DIGITAL_mean',
 'AIR_PRESSURE_DIGITAL_median',
 'AIR_PRESSURE_DIGITAL_variance',
 'AIR_PRESSURE_DIGITAL_max',
 'AIR_PRESSURE_DIGITAL_min',
 'AIR_PRESSURE_DIGITAL_max-min',
 
 'AIR_PRESSURE_DIGITAL_kurtosis',
 'AIR_PRESSURE_DIGITAL_skewness',
 'ENG_OIL_DIGITAL_mean',
 'ENG_OIL_DIGITAL_median',
 'ENG_OIL_DIGITAL_variance',
 'ENG_OIL_DIGITAL_max',
 'ENG_OIL_DIGITAL_min',
 'ENG_OIL_DIGITAL_max-min',
 
 'ENG_OIL_DIGITAL_kurtosis',
 'ENG_OIL_DIGITAL_skewness',
 'eng_coolant_temp_mean',
 'eng_coolant_temp_median',
 'eng_coolant_temp_variance',
 'eng_coolant_temp_max',
 'eng_coolant_temp_min',
 'eng_coolant_temp_max-min',

 'eng_coolant_temp_kurtosis',
 'eng_coolant_temp_skewness',
 'distance_idle%',
 'distance_overrun%',
 'distance_decel%',
 'distance_accel%',
 'time_idle%',
 'time_overrun%',
 'time_decel%',
 'time_accel%',
 '5409',
 '535',
 '525569',
 '6912',
 '5888',
 '6144',
 '131363',
 '131619',
 '8501',
 '5688',
 '262288',
 '131895',
 '4386',
 '69888',
 '5169',
 '4356',
 '4406',
 '131906',
 '267048',
 'total',
 '22',
 '4377',
 '408',
 '267012',
 '4390',
 '9502',
 '4369',
 '1315',
 '4371',
 '65939',
 '4613',
 '1028',
 '1025',
 '1030',
 '1156',
 '4614',
 '66104',
 '1159',
 '65816',
 '275',
 '1344',
 '5376',
 '1316',
 '4374',
 '66370',
 '267024',
 '537',
 '663',
 '9501',
 '70434',
 '267042',
 '257',
 '295',
 '6657',
 '131352',
 '5120',
 '6400',
 '66359',
 '1026',
 '4626',
 '1314',
 '267060',
 '4385',
 '5696',
 '4612',
 '533',
 '5634',
 '4375',
 '5159',
 '74065']

# %% [markdown]
# # EGR

# %%
X = dataAfterFE[col_list]
y = dataAfterFE[['ANN_EGR_N']]

# %%
print(X.shape,y.shape)
# Out:
# (109845, 230) (109845, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1, stratify=y)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (76891, 230) (32954, 230) (76891, 1) (32954, 1)

# %%
#len(y_train), len(y_test)

# %%
import numpy as np
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',np.unique(y['ANN_EGR_N']),y['ANN_EGR_N'])
class_weights
# Out:
# array([ 0.5058252 , 43.41699605])

# %% [markdown]
# # Default Models without Hyperparameter Tuning

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC

# %%
# Random Forest
random_forest = RandomForestClassifier(n_estimators = 100,class_weight={0:class_weights[0],1:class_weights[1]})
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest.score(X_train, y_train)*100))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()

# %%
# K Nearest Neighbor
knn= KNeighborsClassifier(n_neighbors=5,weights='distance')
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
knn_score = ('{:.2f}'.format(knn.score(X_train, y_train)*100))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   app.launch_new_instance()

# %%
# Linear Support Vector Machine
linear_svc = LinearSVC(class_weight={0:class_weights[0],1:class_weights[1]})
linear_svc.fit(X_train, y_train)
y_pred = linear_svc.predict(X_test)
linear_svc_score = ('{:.2f}'.format(linear_svc.score(X_train, y_train)*100))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
# Decision Tree
dt = DecisionTreeClassifier(class_weight={0:class_weights[0],1:class_weights[1]})
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
dt_score = ('{:.2f}'.format(dt.score(X_train, y_train)*100))

# %%
results = pd.DataFrame({'Model': ['Random Forest','K Nearest Neighbor', 'Linear Support Vector Machine', 'Decision Tree'], #'Support Vector Machine',
                        'Score': [random_forest_score,knn_score, linear_svc_score, dt_score]}) # svc_score,

df_results = results.sort_values(by='Score', ascending=False)
df_results = df_results.set_index('Score')
df_results
# Out:
#                                 Model
# Score
# 97.09   Linear Support Vector Machine
# 100.00                  Random Forest
# 100.00             K Nearest Neighbor
# 100.00                  Decision Tree

# %%
import joblib
#saving the model
joblib.dump(dt,'dt_v1.pkl')
joblib.dump(random_forest,'random_forest_v1.pkl')
#joblib.dump(svc,'svc_v1.pkl')
joblib.dump(linear_svc,'linear_svc_v1.pkl')
joblib.dump(knn,'knn_v1.pkl')
# Out:
# ['knn_v1.pkl']

# %%
import joblib
#loading the model
dt_v1 = joblib.load('dt_v1.pkl')
rf_v1 = joblib.load('random_forest_v1.pkl')
knn_v1 = joblib.load('knn_v1.pkl')
lsvm_v1 = joblib.load('linear_svc_v1.pkl')

# %% [markdown]
# ### Predicting for test data using default models

# %%
y_pred_rf = rf_v1.predict(X_test)
y_pred_knn = knn_v1.predict(X_test)
y_pred_svm = lsvm_v1.predict(X_test)
y_pred_dt = dt_v1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve

# %%
#RF model metrics
accuracy_test_rf = accuracy_score(y_test,y_pred_rf)
precision_test_rf = precision_score(y_test, y_pred_rf)
recall_test_rf = recall_score(y_test, y_pred_rf)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[32573     1]
#  [  379     1]]
# accuracy_score on test dataset :  0.9884687746555805
# precision score on test dataset:  0.5
# recall score on test dataset:  0.002631578947368421

# %%
#KNN model metrics
accuracy_test_knn = accuracy_score(y_test,y_pred_knn)
precision_test_knn = precision_score(y_test, y_pred_knn)
recall_test_knn = recall_score(y_test, y_pred_knn)
    
print('knn confusion matrix : ',confusion_matrix(y_test, y_pred_knn,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_knn)
print('precision score on test dataset: ',precision_test_knn)
print('recall score on test dataset: ',recall_test_knn)
# Out:
# knn confusion matrix :  [[32556    18]
#  [  361    19]]
# accuracy_score on test dataset :  0.9884991199854343
# precision score on test dataset:  0.5135135135135135
# recall score on test dataset:  0.05

# %%
#SVM model metrics
accuracy_test_svm = accuracy_score(y_test,y_pred_svm)
precision_test_svm = precision_score(y_test, y_pred_svm)
recall_test_svm = recall_score(y_test, y_pred_svm)
    
print('svm confusion matrix : ',confusion_matrix(y_test, y_pred_svm,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_svm)
print('precision score on test dataset: ',precision_test_svm)
print('recall score on test dataset: ',recall_test_svm)
# Out:
# svm confusion matrix :  [[31975   599]
#  [  372     8]]
# accuracy_score on test dataset :  0.9705346847120229
# precision score on test dataset:  0.013179571663920923
# recall score on test dataset:  0.021052631578947368

# %%
#DT model metrics
accuracy_test_dt = accuracy_score(y_test,y_pred_dt)
precision_test_dt = precision_score(y_test, y_pred_dt)
recall_test_dt = recall_score(y_test, y_pred_dt)
    
print('dt confusion matrix : ',confusion_matrix(y_test, y_pred_dt,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_dt)
print('precision score on test dataset: ',precision_test_dt)
print('recall score on test dataset: ',recall_test_dt)
# Out:
# dt confusion matrix :  [[32199   375]
#  [  340    40]]
# accuracy_score on test dataset :  0.9783030891545791
# precision score on test dataset:  0.0963855421686747
# recall score on test dataset:  0.10526315789473684

# %% [markdown]
# # Attach Statedwell KM

# %%
bucket="relai.poc.data" # aws bucket for sourcing data
folder_base = '/unified_Fx_D3_power_annotated/'  # prev modules: data cleaning/sticthing, feature engineering/extraction, annotations 
extn='.csv' # presently dealing only with csv files

#dataAfterFE_withkm = pd.DataFrame()
#checkdf = pd.Dataframe("",column = ['tocheck'])
checklist = [] 
listofdf = []
i=1
for v,df in dataAfterFE.groupby('vin'):
    #print(str(i)+':'+v)
    temp = pd.read_csv('s3://{}/{}{}{}'.format(bucket, folder_base, v, extn))
    if df.shape[0] == temp.shape[0]:
        pass
    else:
        checklist.append(v)
        
    listofdf.append(temp)
    #print(v + 'read')
    #df['statedwell_km'] = temp['statedwell_km'].values
    #dataAfterFE_withkm = dataAfterFE_withkm.append(df)
    i+=1

# %%
checklist
# Out:
# ['MB1KACHD7KPJG5914']

# %%
dataAfterFE_withkm = pd.concat(listofdf)
len(dataAfterFE_withkm['statedwell_km'])
# Out:
# 109808

# %%
dataAfterFE_withkm_avoid5914 = dataAfterFE_withkm[dataAfterFE_withkm['vin'] != 'MB1KACHD7KPJG5914']
dataAfterFE_avoid5914 = dataAfterFE[dataAfterFE['vin'] != 'MB1KACHD7KPJG5914']

# %%
X_C = dataAfterFE_avoid5914[col_list]
y_c = dataAfterFE_avoid5914[['ANN_EGR_N']]

# %%
dataAfterFE_withkm_avoid5914.shape[0],len(X_C),len(y_c)
# Out:
# (109756, 109756, 109756)

# %%
y_test.columns
# Out:
# Index(['ANN_EGR_N'], dtype='object')

# %%
y_c.columns
# Out:
# Index(['ANN_EGR_N'], dtype='object')

# %% [markdown]
# ### Predicting for whole data using default models

# %%
#fitting the model to whole dataset
y_p_rf = rf_v1.predict(X_C)
y_p_knn = knn_v1.predict(X_C)
y_p_svm = lsvm_v1.predict(X_C)
y_p_dt = dt_v1.predict(X_C)

# %%
#RF model metrics for whole data
accuracy_test_rf = accuracy_score(y_c['ANN_EGR_N'],y_p_rf)
precision_test_rf = precision_score(y_c['ANN_EGR_N'],y_p_rf)
recall_test_rf = recall_score(y_c['ANN_EGR_N'],y_p_rf)
    
print('rf confusion matrix : ',confusion_matrix(y_c['ANN_EGR_N'],y_p_rf,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[108505      1]
#  [   377    873]]
# accuracy_score on test dataset :  0.9965559969386639
# precision score on test dataset:  0.9988558352402745
# recall score on test dataset:  0.6984

# %%
#KNN model metrics for whole data
accuracy_test_knn = accuracy_score(y_c['ANN_EGR_N'],y_p_knn)
precision_test_knn = precision_score(y_c['ANN_EGR_N'],y_p_knn)
recall_test_knn = recall_score(y_c['ANN_EGR_N'],y_p_knn)
    
print('knn confusion matrix : ',confusion_matrix(y_c['ANN_EGR_N'],y_p_knn,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_knn)
print('precision score on test dataset: ',precision_test_knn)
print('recall score on test dataset: ',recall_test_knn)
# Out:
# knn confusion matrix :  [[108488     18]
#  [   357    893]]
# accuracy_score on test dataset :  0.9965833302962936
# precision score on test dataset:  0.9802414928649835
# recall score on test dataset:  0.7144

# %%
#SVM model metrics for whole data
accuracy_test_svm = accuracy_score(y_c['ANN_EGR_N'],y_p_svm)
precision_test_svm = precision_score(y_c['ANN_EGR_N'],y_p_svm)
recall_test_svm = recall_score(y_c['ANN_EGR_N'],y_p_svm)
    
print('svm confusion matrix : ',confusion_matrix(y_c['ANN_EGR_N'],y_p_svm,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_svm)
print('precision score on test dataset: ',precision_test_svm)
print('recall score on test dataset: ',recall_test_svm)
# Out:
# svm confusion matrix :  [[106507   1999]
#  [  1195     55]]
# accuracy_score on test dataset :  0.9708990852436313
# precision score on test dataset:  0.026777020447906523
# recall score on test dataset:  0.044

# %%
#DT model metrics for whole data
accuracy_test_dt = accuracy_score(y_c['ANN_EGR_N'],y_p_dt)
precision_test_dt = precision_score(y_c['ANN_EGR_N'],y_p_dt)
recall_test_dt = recall_score(y_c['ANN_EGR_N'],y_p_dt)
    
print('dt confusion matrix : ',confusion_matrix(y_c['ANN_EGR_N'],y_p_dt,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_dt)
print('precision score on test dataset: ',precision_test_dt)
print('recall score on test dataset: ',recall_test_dt)
# Out:
# dt confusion matrix :  [[108131    375]
#  [   337    913]]
# accuracy_score on test dataset :  0.9935128831225628
# precision score on test dataset:  0.7088509316770186
# recall score on test dataset:  0.7304

# %%
dataAfterFE_withkm_avoid5914['y_pred_dt'] = y_p_dt.ravel()
dataAfterFE_withkm_avoid5914['y_pred_knn'] = y_p_knn.ravel()
dataAfterFE_withkm_avoid5914['y_pred_rf'] = y_p_rf.ravel()
dataAfterFE_withkm_avoid5914['y_pred_svm'] = y_p_svm.ravel()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#dataAfterFE_avoid5914[dataAfterFE_avoid5914.columns.isin()]
list(set(dataAfterFE_withkm.columns).difference(dataAfterFE_avoid5914.columns))
# Out:
# ['BAT_CHARGING_CURRENT_km',
#  'AMBIENT_AIR_TEMP_km',
#  'ENGINE_FUEL_TEMP_1_km',
#  'AIR_PRESSURE_DIGITAL_km',
#  'ENGINE_OIL_TEMP_km',
#  'VEHICAL_BATTERY_POTENTIAL_km',
#  'AIR_PRESSURE_1_km',
#  'engine_speed_km',
#  'ENG_OIL_DIGITAL_km',
#  'ENGINE_OIL_PRESSURE_km',
#  'ENGINE_AIR_INLET_PRESSURE_km',
#  'ANN_Radiator',
#  'code_odo',
#  'ANN_EGR',
#  'ACTUAL_ENGINE_TORQUE_km',
#  'ENGINE_INTAKE_M_TEMPERATURE_km',
#  'statedwell_timestamp',
#  'ENGINE_INTAKE_M_PRESSURE_km',
#  'AIR_PRESSURE_2_km',
#  'eng_coolant_temp_km',
#  'statedwell_km',
#  'Power_km',
#  'THROTTLE_POS_km',
#  'FUEL_CONSUM_km']

# %%
dataAfterFE_withkm.to_csv("AI_03_EGR_dataAfterFE_withkm.csv")

# %%
X_C_km = dataAfterFE_avoid5914.copy()
X_C_km['y_pred_dt'] = y_p_dt.ravel()
X_C_km['y_pred_knn'] = y_p_knn.ravel()
X_C_km['y_pred_rf'] = y_p_rf.ravel()
X_C_km['y_pred_svm'] = y_p_svm.ravel()
X_C_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
list(X_C_km.columns)
# Out:
# ['Power_mean',
#  'Power_median',
#  'Power_variance',
#  'Power_max',
#  'Power_min',
#  'Power_max-min',
#  'Power_kurtosis',
#  'Power_skewness',
#  'engine_speed_mean',
#  'engine_speed_median',
#  'engine_speed_variance',
#  'engine_speed_max',
#  'engine_speed_min',
#  'engine_speed_max-min',
#  'engine_speed_kurtosis',
#  'engine_speed_skewness',
#  'VEHICAL_BATTERY_POTENTIAL_mean',
#  'VEHICAL_BATTERY_POTENTIAL_median',
#  'VEHICAL_BATTERY_POTENTIAL_variance',
#  'VEHICAL_BATTERY_POTENTIAL_max',
#  'VEHICAL_BATTERY_POTENTIAL_min',
#  'VEHICAL_BATTERY_POTENTIAL_max-min',
#  'VEHICAL_BATTERY_POTENTIAL_kurtosis',
#  'VEHICAL_BATTERY_POTENTIAL_skewness',
#  'FUEL_CONSUM_mean',
#  'FUEL_CONSUM_median',
#  'FUEL_CONSUM_variance',
#  'FUEL_CONSUM_max',
#  'FUEL_CONSUM_min',
#  'FUEL_CONSUM_max-min',
#  'FUEL_CONSUM_kurtosis',
#  'FUEL_CONSUM_skewness',
#  'THROTTLE_POS_mean',
#  'THROTTLE_POS_median',
#  'THROTTLE_POS_variance',
#  'THROTTLE_POS_max',
#  'THROTTLE_POS_min',
#  'THROTTLE_POS_max-min',
#  'THROTTLE_POS_kurtosis',
#  'THROTTLE_POS_skewness',
#  'ACTUAL_ENGINE_TORQUE_mean',
#  'ACTUAL_ENGINE_TORQUE_median',
#  'ACTUAL_ENGINE_TORQUE_variance',
#  'ACTUAL_ENGINE_TORQUE_max',
#  'ACTUAL_ENGINE_TORQUE_min',
#  'ACTUAL_ENGINE_TORQUE_max-min',
#  'ACTUAL_ENGINE_TORQUE_kurtosis',
#  'ACTUAL_ENGINE_TORQUE_skewness',
#  'ENGINE_OIL_TEMP_mean',
#  'ENGINE_OIL_TEMP_median',
#  'ENGINE_OIL_TEMP_variance',
#  'ENGINE_OIL_TEMP_max',
#  'ENGINE_OIL_TEMP_min',
#  'ENGINE_OIL_TEMP_max-min',
#  'ENGINE_OIL_TEMP_kurtosis',
#  'ENGINE_OIL_TEMP_skewness',
#  'ENGINE_INTAKE_M_PRESSURE_mean',
#  'ENGINE_INTAKE_M_PRESSURE_median',
#  'ENGINE_INTAKE_M_PRESSURE_variance',
#  'ENGINE_INTAKE_M_PRESSURE_max',
#  'ENGINE_INTAKE_M_PRESSURE_min',
#  'ENGINE_INTAKE_M_PRESSURE_max-min',
#  'ENGINE_INTAKE_M_PRESSURE_kurtosis',
#  'ENGINE_INTAKE_M_PRESSURE_skewness',
#  'ENGINE_INTAKE_M_TEMPERATURE_mean',
#  'ENGINE_INTAKE_M_TEMPERATURE_median',
#  'ENGINE_INTAKE_M_TEMPERATURE_variance',
#  'ENGINE_INTAKE_M_TEMPERATURE_max',
#  'ENGINE_INTAKE_M_TEMPERATURE_min',
#  'ENGINE_INTAKE_M_TEMPERATURE_max-min',
#  'ENGINE_INTAKE_M_TEMPERATURE_kurtosis',
#  'ENGINE_INTAKE_M_TEMPERATURE_skewness',
#  'ENGINE_AIR_INLET_PRESSURE_mean',
#  'ENGINE_AIR_INLET_PRESSURE_median',
#  'ENGINE_AIR_INLET_PRESSURE_variance',
#  'ENGINE_AIR_INLET_PRESSURE_max',
#  'ENGINE_AIR_INLET_PRESSURE_min',
#  'ENGINE_AIR_INLET_PRESSURE_max-min',
#  'ENGINE_AIR_INLET_PRESSURE_kurtosis',
#  'ENGINE_AIR_INLET_PRESSURE_skewness',
#  'AMBIENT_AIR_TEMP_mean',
#  'AMBIENT_AIR_TEMP_median',
#  'AMBIENT_AIR_TEMP_variance',
#  'AMBIENT_AIR_TEMP_max',
#  'AMBIENT_AIR_TEMP_min',
#  'AMBIENT_AIR_TEMP_max-min',
#  'AMBIENT_AIR_TEMP_kurtosis',
#  'AMBIENT_AIR_TEMP_skewness',
#  'ENGINE_FUEL_TEMP_1_mean',
#  'ENGINE_FUEL_TEMP_1_median',
#  'ENGINE_FUEL_TEMP_1_variance',
#  'ENGINE_FUEL_TEMP_1_max',
#  'ENGINE_FUEL_TEMP_1_min',
#  'ENGINE_FUEL_TEMP_1_max-min',
#  'ENGINE_FUEL_TEMP_1_kurtosis',
#  'ENGINE_FUEL_TEMP_1_skewness',
#  'BAT_CHARGING_CURRENT_mean',
#  'BAT_CHARGING_CURRENT_median',
#  'BAT_CHARGING_CURRENT_variance',
#  'BAT_CHARGING_CURRENT_max',
#  'BAT_CHARGING_CURRENT_min',
#  'BAT_CHARGING_CURRENT_max-min',
#  'BAT_CHARGING_CURRENT_kurtosis',
#  'BAT_CHARGING_CURRENT_skewness',
#  'ENGINE_OIL_PRESSURE_mean',
#  'ENGINE_OIL_PRESSURE_median',
#  'ENGINE_OIL_PRESSURE_variance',
#  'ENGINE_OIL_PRESSURE_max',
#  'ENGINE_OIL_PRESSURE_min',
#  'ENGINE_OIL_PRESSURE_max-min',
#  'ENGINE_OIL_PRESSURE_kurtosis',
#  'ENGINE_OIL_PRESSURE_skewness',
#  'AIR_PRESSURE_1_mean',
#  'AIR_PRESSURE_1_median',
#  'AIR_PRESSURE_1_variance',
#  'AIR_PRESSURE_1_max',
#  'AIR_PRESSURE_1_min',
#  'AIR_PRESSURE_1_max-min',
#  'AIR_PRESSURE_1_kurtosis',
#  'AIR_PRESSURE_1_skewness',
#  'AIR_PRESSURE_2_mean',
#  'AIR_PRESSURE_2_median',
#  'AIR_PRESSURE_2_variance',
#  'AIR_PRESSURE_2_max',
#  'AIR_PRESSURE_2_min',
#  'AIR_PRESSURE_2_max-min',
#  'AIR_PRESSURE_2_kurtosis',
#  'AIR_PRESSURE_2_skewness',
#  'AIR_PRESSURE_DIGITAL_mean',
#  'AIR_PRESSURE_DIGITAL_median',
#  'AIR_PRESSURE_DIGITAL_variance',
#  'AIR_PRESSURE_DIGITAL_max',
#  'AIR_PRESSURE_DIGITAL_min',
#  'AIR_PRESSURE_DIGITAL_max-min',
#  'AIR_PRESSURE_DIGITAL_kurtosis',
#  'AIR_PRESSURE_DIGITAL_skewness',
#  'ENG_OIL_DIGITAL_mean',
#  'ENG_OIL_DIGITAL_median',
#  'ENG_OIL_DIGITAL_variance',
#  'ENG_OIL_DIGITAL_max',
#  'ENG_OIL_DIGITAL_min',
#  'ENG_OIL_DIGITAL_max-min',
#  'ENG_OIL_DIGITAL_kurtosis',
#  'ENG_OIL_DIGITAL_skewness',
#  'eng_coolant_temp_mean',
#  'eng_coolant_temp_median',
#  'eng_coolant_temp_variance',
#  'eng_coolant_temp_max',
#  'eng_coolant_temp_min',
#  'eng_coolant_temp_max-min',
#  'eng_coolant_temp_kurtosis',
#  'eng_coolant_temp_skewness',
#  'distance_idle%',
#  'distance_overrun%',
#  'distance_decel%',
#  'distance_accel%',
#  'time_idle%',
#  'time_overrun%',
#  'time_decel%',
#  'time_accel%',
#  '5409',
#  '535',
#  '525569',
#  '6912',
#  '5888',
#  '6144',
#  '131363',
#  '131619',
#  '8501',
#  '5688',
#  '262288',
#  '131895',
#  '4386',
#  '69888',
#  '5169',
#  '4356',
#  '4406',
#  '131906',
#  '267048',
#  'total',
#  '22',
#  '4377',
#  '408',
#  '267012',
#  '4390',
#  '9502',
#  '4369',
#  '1315',
#  '4371',
#  '65939',
#  '4613',
#  '1028',
#  '1025',
#  '1030',
#  '1156',
#  '4614',
#  '66104',
#  '1159',
#  '65816',
#  '275',
#  '1344',
#  '5376',
#  '1316',
#  '4374',
#  '66370',
#  '267024',
#  '537',
#  '663',
#  '9501',
#  '70434',
#  '267042',
#  '257',
#  '295',
#  '6657',
#  '131352',
#  '5120',
#  '6400',
#  '66359',
#  '1026',
#  '4626',
#  '1314',
#  '267060',
#  '4385',
#  '5696',
#  '4612',
#  '533',
#  '5634',
#  '4375',
#  '5159',
#  '74065',
#  'r_error',
#  'ANN_EGR_N',
#  'ANN_AIR_FILTER_N',
#  'vin',
#  'ANN_EGR_KM',
#  'ANN_AIR_FILTER_KM',
#  'y_pred_dt',
#  'y_pred_knn',
#  'y_pred_rf',
#  'y_pred_svm',
#  'statedwell_km']

# %%
dataAfterFE_withkm_avoid5914['statedwell_km'].min()
# Out:
# 100.0

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_dt']
        df3=df1[df1['ANN_EGR_N']!=0][['ANN_EGR_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_EGR_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_km[X_C_km['ANN_EGR_N']==1][['vin','ANN_EGR_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_EGR_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_knn_80.csv')

# %%
df_EGR_vinkm_formatted_compiled.head()
# Out:
#                  vin  1st_prediction_instance_km Predicted as Failed  \
# 0  MB1A3EHD5JADJ1088                     86862.6                   Y
# 1  MB1A3EHD5JAWJ7589                     71566.0                   Y
# 2  MB1A3EHD8JAYJ5583                     84278.1                   Y
# 3  MB1CTCHD0JEWC3057                     40390.1                   Y
# 4  MB1CTCHD2JPAE5230                     78850.6                   Y
#
#   Actual Failed  ANN_EGR_KM  Predicted in advance km
# 0             Y     88633.0                   1770.4
# 1             Y     73500.0                   1934.0
# 2             Y     86200.0                   1921.9
# 3             Y     40538.0                    147.9
# 4             Y     80760.0                   1909.4

# %% [markdown]
# # RF FOR EGR

# %% [markdown]
# ### RF Tuned 0

# %%
# Random Forest tuned
random_forest_1 = RandomForestClassifier(n_estimators = 90, max_depth = 11, min_samples_split = 450, class_weight={0:class_weights[0],1:class_weights[1]})
random_forest_1.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_1.score(X_train, y_train)*100))
random_forest_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()
# '93.78'

# %%
y_pred_rf = random_forest_1.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf)
precision_test_rf = precision_score(y_test, y_pred_rf)
recall_test_rf = recall_score(y_test, y_pred_rf)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[30444  2130]
#  [  264   116]]
# accuracy_score on test dataset :  0.9273532803301572
# precision score on test dataset:  0.051647373107747106
# recall score on test dataset:  0.30526315789473685

# %% [markdown]
# ### RF Tuned 1

# %%
# Random Forest tuned
random_forest_2 = RandomForestClassifier(n_estimators = 90, max_features = 'log2', max_depth = 12, min_samples_split = 500, class_weight={0:0.35,1:35})
random_forest_2.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_2.score(X_train, y_train)*100))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()

# %%
random_forest_2
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight={0: 0.35, 1: 35}, criterion='gini',
#                        max_depth=12, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=500, min_weight_fraction_leaf=0.0,
#                        n_estimators=90, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
import joblib
joblib.dump(random_forest_2,'EGR_RFTuned1.pkl')
# Out:
# ['EGR_RFTuned1.pkl']

# %%
# import joblib
# random_forest_2 = joblib.load('rf_tuned.pkl')

# %%
# random_forest_score = ('{:.2f}'.format(random_forest_2.score(X_train, y_train)*100))
# random_forest_score

# %%
y_pred_rf2 = random_forest_2.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf2)
precision_test_rf = precision_score(y_test, y_pred_rf2)
recall_test_rf = recall_score(y_test, y_pred_rf2)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[29385  3189]
#  [  238   142]]
# accuracy_score on test dataset :  0.8960065545912484
# precision score on test dataset:  0.04262984088862203
# recall score on test dataset:  0.3736842105263158

# %%
y_pred_rf2 = random_forest_2.predict(X_C)
accuracy_test_rf = accuracy_score(y_c,y_pred_rf2)
precision_test_rf = precision_score(y_c, y_pred_rf2)
recall_test_rf = recall_score(y_c, y_pred_rf2)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred_rf2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[98110 10396]
#  [  306   944]]
# accuracy_score on test dataset :  0.9024928022158242
# precision score on test dataset:  0.08324514991181658
# recall score on test dataset:  0.7552

# %%
import joblib
#saving the model
joblib.dump(random_forest_2,'rf_tuned.pkl')
# Out:
# ['rf_tuned.pkl']

# %%
X_C_km = dataAfterFE_avoid5914.copy()
X_C_km['y_pred_rf2'] = y_pred_rf2.ravel()
X_C_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_rf2']
        df3=df1[df1['ANN_EGR_N']!=0][['ANN_EGR_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_EGR_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_km[X_C_km['ANN_EGR_N']==1][['vin','ANN_EGR_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_EGR_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_knn_80.csv')

# %%
df_EGR_vinkm_formatted_compiled.to_csv('rf_tuned_vinpred.csv')

# %%
df_EGR_vinkm_formatted_compiled.head()
# Out:
#                  vin  1st_prediction_instance_km Predicted as Failed  \
# 0  MB1A3EHD5JADJ1088                     86662.6                   Y
# 1  MB1A3EHD5JAWJ7589                     67466.0                   Y
# 2  MB1A3EHD8JAYJ5583                     82678.1                   Y
# 3  MB1CTCHD0JEWC3057                     40390.1                   Y
# 4  MB1CTCHD2JPAE5230                     78750.6                   Y
#
#   Actual Failed  ANN_EGR_KM  Predicted in advance km
# 0             Y     88633.0                   1970.4
# 1             Y     73500.0                   6034.0
# 2             Y     86200.0                   3521.9
# 3             Y     40538.0                    147.9
# 4             Y     80760.0                   2009.4

# %%
df_EGR_vinkm_formatted_compiled['vin'].value_counts()
# Out:
# MB1UPKHD9JPDD7217    3
# MB1KACHD3JAGH6461    2
# MB1A3EHD8JAYJ4904    1
# MB1TRKHD9JPDD3268    1
# MB1CTCHD7JAXJ6492    1
#                     ..
# MB1NACHD3JPHB6743    1
# MB1TRKHD4JRYZ3852    1
# MB1KACHD6KPGH8333    1
# MB1UPKHD4JPCD8479    1
# MB1KACHD4JRBY2583    1
# Name: vin, Length: 1121, dtype: int64

# %%
cm=[]
for ind,row in df_EGR_vinkm_formatted_compiled.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
from collections import Counter
Counter(cm)  #Totally avoided False negative
# Out:
# Counter({'TP': 77, 'FP': 630, 'TN': 416, 'FN': 1})

# %%
df_EGR_vinkm_formatted_compiled.to_csv('EGR_RFTuned1.csv')

# %%
(420+78) /1124
# Out:
# 0.4430604982206406

# %%
78 / (78+626)
# Out:
# 0.11079545454545454

# %%
626+420+78
# Out:
# 1124

# %% [markdown]
# -- END of ALGORITHM

# %% [markdown]
# ### RF Tuned 3

# %%
# Random Forest tuned
random_forest_3 = RandomForestClassifier(n_estimators = 100, max_features = 'log2', max_depth = 12, min_samples_split = 250, class_weight={0:0.57,1:40})
random_forest_3.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_2.score(X_train, y_train)*100))
random_forest_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()
# '90.50'

# %%
random_forest_3
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight={0: 0.57, 1: 40}, criterion='gini',
#                        max_depth=12, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=250, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
joblib.dump(random_forest_3,'EGR_RFTuned2.pkl')
# Out:
# ['EGR_RFTuned2.pkl']

# %%
y_pred_rf3 = random_forest_3.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf3)
precision_test_rf = precision_score(y_test, y_pred_rf3)
recall_test_rf = recall_score(y_test, y_pred_rf3)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf3,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[31891   683]
#  [  306    74]]
# accuracy_score on test dataset :  0.9699884687746556
# precision score on test dataset:  0.0977542932628798
# recall score on test dataset:  0.19473684210526315

# %%
y_pred_rf3 = random_forest_3.predict(X_C)
accuracy_test_rf = accuracy_score(y_c,y_pred_rf3)
precision_test_rf = precision_score(y_c, y_pred_rf3)
recall_test_rf = recall_score(y_c, y_pred_rf3)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred_rf3,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[106321   2185]
#  [   543    707]]
# accuracy_score on test dataset :  0.9751448667954371
# precision score on test dataset:  0.24446749654218533
# recall score on test dataset:  0.5656

# %%
X_C_km = dataAfterFE_avoid5914.copy()
X_C_km['y_pred_rf3'] = y_pred_rf3.ravel()
X_C_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_rf3']
        df3=df1[df1['ANN_EGR_N']!=0][['ANN_EGR_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_EGR_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_km[X_C_km['ANN_EGR_N']==1][['vin','ANN_EGR_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_EGR_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_knn_80.csv')

# %%
cm=[]
for ind,row in df_EGR_vinkm_formatted_compiled.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
Counter(cm)
# Out:
# Counter({'TP': 75, 'FP': 289, 'TN': 757, 'FN': 3})

# %%
df_EGR_vinkm_formatted_compiled.to_csv('EGR_RFTuned2.csv')

# %%
75/(75+298)
# Out:
# 0.20107238605898123

# %%
75/(75+3)
# Out:
# 0.9615384615384616

# %%
y_test.columns
# Out:
# Index(['ANN_EGR_N'], dtype='object')

# %% [markdown]
# ### RF Tuned 4

# %%
# Random Forest tuned
random_forest_4 = RandomForestClassifier(n_estimators = 50, max_features = 'log2', max_depth = 12, min_samples_split = 450, class_weight={0:0.6,1:40})
random_forest_4.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_2.score(X_train, y_train)*100))
random_forest_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()
# '90.50'

# %%
random_forest_4
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                        class_weight={0: 0.6, 1: 40}, criterion='gini',
#                        max_depth=12, max_features='log2', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=450, min_weight_fraction_leaf=0.0,
#                        n_estimators=50, n_jobs=None, oob_score=False,
#                        random_state=None, verbose=0, warm_start=False)

# %%
joblib.dump(random_forest_4,'EGR_RFTuned3.pkl')
# Out:
# ['EGR_RFTuned3.pkl']

# %%
y_pred_rf4 = random_forest_4.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf4)
precision_test_rf = precision_score(y_test, y_pred_rf4)
recall_test_rf = recall_score(y_test, y_pred_rf4)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf4,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[31774   800]
#  [  316    64]]
# accuracy_score on test dataset :  0.9661346118832311
# precision score on test dataset:  0.07407407407407407
# recall score on test dataset:  0.16842105263157894

# %%
y_pred_rf4 = random_forest_4.predict(X_C)
accuracy_test_rf = accuracy_score(y_c,y_pred_rf4)
precision_test_rf = precision_score(y_c, y_pred_rf4)
recall_test_rf = recall_score(y_c, y_pred_rf4)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred_rf4,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[105897   2609]
#  [   490    760]]
# accuracy_score on test dataset :  0.9717646415685702
# precision score on test dataset:  0.22558622736717127
# recall score on test dataset:  0.608

# %%
X_C_km = dataAfterFE_avoid5914.copy()
X_C_km['y_pred_rf3'] = y_pred_rf4.ravel()
X_C_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_rf3']
        df3=df1[df1['ANN_EGR_N']!=0][['ANN_EGR_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_EGR_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_km[X_C_km['ANN_EGR_N']==1][['vin','ANN_EGR_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_EGR_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_knn_80.csv')

# %%
cm=[]
for ind,row in df_EGR_vinkm_formatted_compiled.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
Counter(cm)
# Out:
# Counter({'TP': 77, 'FP': 349, 'TN': 697, 'FN': 1})

# %%
df_EGR_vinkm_formatted_compiled.to_csv('EGR_RFTuned3.csv')

# %% [markdown]
# ### SUMMARY:

# %% [raw]
# - Upon multiple training, Random Forest models gives more promising results comparing to other techniques.
# - The best results have been achieved in two different random forest models with tuned hyperparameters
# - In RF1 - 'TN': 420, 'FP': 626, 'FN': 0, 'TP': 78.
#   Accuracy - 0.4430604982206406
#   precision - 0.11079545454545454
#   recall - 1.0
# - In RF2 - 'TN': 748, 'FP': 298, 'FN': 3, 'TP': 75.
#   Accuracy - 0.7335115864527
#   precision - 0.20107238605898123
#   recall - 0.96

# %% [markdown]
# # SVM FOR EGR

# %% [markdown]
# ### SVM 1 Using Kernel Approximation

# %%
#using kernel approximation - nystroem
from sklearn import svm
from sklearn.kernel_approximation import Nystroem
data = X_train #/ 16.
clf = svm.LinearSVC(class_weight={0:0.5,1:45})
feature_map_nystroem = Nystroem(gamma=.4,
                                 random_state=1,
                                 n_components=500)
data_transformed = feature_map_nystroem.fit_transform(data)
clf.fit(data_transformed, y_train)
clf.score(data_transformed, y_train)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.6634196459923788

# %%
data_transformed_test = feature_map_nystroem.fit_transform(X_test)
y_pred = clf.predict(data_transformed_test)

# %%
accuracy_test_rf = accuracy_score(y_test,y_pred)
precision_test_rf = precision_score(y_test, y_pred)
recall_test_rf = recall_score(y_test, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[18870 13704]
#  [  180   200]]
# accuracy_score on test dataset :  0.5786854403107362
# precision score on test dataset:  0.014384349827387802
# recall score on test dataset:  0.5263157894736842

# %% [markdown]
# ### SVM 2 Using Kernel Approximation with addded HyperParameter

# %%
#using kernel approximation - nystroem
from sklearn import svm
from sklearn.kernel_approximation import Nystroem
data = X_train #/ 16.
clf = svm.LinearSVC(class_weight={0:0.4,1:35}, dual = False, C = 0.7)
feature_map_nystroem = Nystroem(gamma=.45,
                                 random_state=1,
                                 n_components=500)
data_transformed = feature_map_nystroem.fit_transform(data)
clf.fit(data_transformed, y_train)
clf.score(data_transformed, y_train)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6736158978293949

# %%
data_test = X_test #/16
data_transformed_test = feature_map_nystroem.fit_transform(data_test)
y_pred = clf.predict(data_transformed_test)

# %%
accuracy_test_rf = accuracy_score(y_test,y_pred)
precision_test_rf = precision_score(y_test, y_pred)
recall_test_rf = recall_score(y_test, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[18957 13617]
#  [  182   198]]
# accuracy_score on test dataset :  0.5812647933483037
# precision score on test dataset:  0.014332247557003257
# recall score on test dataset:  0.5210526315789473

# %%
data_test = X_C #/16
data_transformed_test = feature_map_nystroem.fit_transform(data_test)
y_pred = clf.predict(data_transformed_test)

# %%
accuracy_test_rf = accuracy_score(y_c,y_pred)
precision_test_rf = precision_score(y_c, y_pred)
recall_test_rf = recall_score(y_c, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[55581 52925]
#  [  681   569]]
# accuracy_score on test dataset :  0.5115893436349721
# precision score on test dataset:  0.010636706920402288
# recall score on test dataset:  0.4552

# %% [markdown]
# ### SVM 3 Using Kernel Approximation - Log Model - SGD Classifier

# %%
# using kernel approximation - rbf sampler and sgd classifier - log
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier
rbf_feature = RBFSampler(gamma=.35, random_state=1)
X_features = rbf_feature.fit_transform(X_train)
clf_1 = SGDClassifier(loss = 'log', max_iter=5, class_weight={0:0.4,1:20})
clf_1.fit(X_features, y_train)

clf_1.score(X_features, y_train)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/linear_model/_stochastic_gradient.py:557: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# 0.8004187746290203

# %%
X_features_test = rbf_feature.fit_transform(X_test)
y_pred = clf_1.predict(X_features_test)

# %%
y_pred_proba= clf_1.predict_proba(X_features_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve,roc_auc_score
accuracy_test_rf = accuracy_score(y_test,y_pred)
precision_test_rf = precision_score(y_test, y_pred)
recall_test_rf = recall_score(y_test, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[26216  6358]
#  [  244   136]]
# accuracy_score on test dataset :  0.7996601323056381
# precision score on test dataset:  0.020942408376963352
# recall score on test dataset:  0.35789473684210527

# %%
roc_auc_score(y_test, y_pred_proba[:,1])
# Out:
# 0.6343985193228052

# %%
import matplotlib.pyplot as plt
#y_pred_proba = clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba[:,1])
auc = roc_auc_score(y_test, y_pred_proba[:,1])
plt.plot(fpr,tpr,label="data, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ### SVM 4 Using Kernel Approximation - Hinge (LinearSVC) model - SGD Classifier

# %%
# using kernel approximation - rbf sampler and sgd classifier - hinge 
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier
rbf_feature = RBFSampler(gamma=.4, random_state=1)
X_features = rbf_feature.fit_transform(X_train)
clf_2 = SGDClassifier(max_iter=5, class_weight={0:0.3,1:35}, random_state = 1)
clf_2.fit(X_features, y_train)

clf_2.score(X_features, y_train)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/linear_model/_stochastic_gradient.py:557: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# 0.7712736210999988

# %%
X_features_test = rbf_feature.fit_transform(X_test)
y_pred = clf_2.predict(X_features_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve,roc_auc_score
accuracy_test_rf = accuracy_score(y_test,y_pred)
precision_test_rf = precision_score(y_test, y_pred)
recall_test_rf = recall_score(y_test, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[25082  7492]
#  [  246   134]]
# accuracy_score on test dataset :  0.7651878375917947
# precision score on test dataset:  0.017571466037241017
# recall score on test dataset:  0.3526315789473684

# %% [markdown]
# # KNN FOR EGR

# %%
# K Nearest Neighbor
knn= KNeighborsClassifier(n_neighbors=10,weights='distance')
knn.fit(X_train, y_train)
knn_score = ('{:.2f}'.format(knn.score(X_train, y_train)*100))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   app.launch_new_instance()

# %%
knn_score
# Out:
# '100.00'

# %%
y_pred = knn.predict(X_test)

# %%
#KNN model metrics for whole data
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve,roc_auc_score
accuracy_test_knn = accuracy_score(y_test['ANN_EGR_N'],y_pred)
precision_test_knn = precision_score(y_test['ANN_EGR_N'],y_pred)
recall_test_knn = recall_score(y_test['ANN_EGR_N'],y_pred)
    
print('knn confusion matrix : ',confusion_matrix(y_test['ANN_EGR_N'],y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_knn)
print('precision score on test dataset: ',precision_test_knn)
print('recall score on test dataset: ',recall_test_knn)
# Out:
# knn confusion matrix :  [[32572     2]
#  [  372     8]]
# accuracy_score on test dataset :  0.9886508466347029
# precision score on test dataset:  0.8
# recall score on test dataset:  0.021052631578947368

# %%
from sklearn.ensemble import BaggingClassifier
kn1= KNeighborsClassifier(n_neighbors=10,weights='uniform')
kn2= KNeighborsClassifier(n_neighbors=10,weights='distance')
bgg= BaggingClassifier(kn2,n_estimators=100,max_features=0.7,verbose=0)#, max_features=0.5

# %%
bgg.fit(X_train, y_train)
bgg_score = ('{:.2f}'.format(bgg.score(X_train, y_train)*100))
bgg_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-24-50764438b57c> in <module>
# ----> 1 bgg.fit(X_train, y_train)
#       2 bgg_score = ('{:.2f}'.format(bgg.score(X_train, y_train)*100))
#       3 bgg_score
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/ensemble/_bagging.py in fit(self, X, y, sample_weight)
#     241         self : object
#     242         """
# --> 243         return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#     244
#     245     def _parallel_args(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/ensemble/_bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     378                 total_n_estimators,
#     379                 verbose=self.verbose)
# --> 380             for i in range(n_jobs))
#     381
#     382         # Reduce
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/ensemble/_bagging.py in _parallel_build_estimators(n_estimators, ensemble, X, y, sample_weight, seeds, total_n_estimators, verbose)
#     111
#     112         else:
# --> 113             estimator.fit((X[indices])[:, features], y[indices])
#     114
#     115         estimators.append(estimator)
#
# MemoryError: Unable to allocate 135. MiB for an array with shape (76891, 230) and data type float64

# %% [markdown]
# # AIR FILTER

# %%
# For air filter
X = dataAfterFE[col_list]
y = dataAfterFE[['ANN_AIR_FILTER_N']]

# %%
y.columns
# Out:
# Index(['ANN_AIR_FILTER_N'], dtype='object')

# %%
y['ANN_AIR_FILTER_N'].value_counts()
# Out:
# 0    109084
# 1       761
# Name: ANN_AIR_FILTER_N, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1, stratify=y)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (76891, 230) (32954, 230) (76891, 1) (32954, 1)

# %%
import numpy as np
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',np.unique(y['ANN_AIR_FILTER_N']),y['ANN_AIR_FILTER_N'])
class_weights
# Out:
# array([ 0.50348814, 72.17148489])

# %% [markdown]
# # RF FOR AIR FILTER

# %% [markdown]
# ### RF Tuned 1

# %%
# Random Forest tuned
from sklearn.ensemble import RandomForestClassifier
random_forest_af_2 = RandomForestClassifier(n_estimators = 110, max_features = 'log2', max_depth = 12, min_samples_split = 550, class_weight={0:0.4,1:70})
random_forest_af_2.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_af_2.score(X_train, y_train)*100))
random_forest_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# '93.59'

# %%
y_pred_proba= random_forest_af_2.predict_proba(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve,roc_auc_score

# %%
import matplotlib.pyplot as plt
#y_pred_proba = clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba[:,1])
auc = roc_auc_score(y_test, y_pred_proba[:,1])
plt.plot(fpr,tpr,label="data, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf_af_2)
precision_test_rf = precision_score(y_test, y_pred_rf_af_2)
recall_test_rf = recall_score(y_test, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[30617  2109]
#  [   99   129]]
# accuracy_score on test dataset :  0.932997511682952
# precision score on test dataset:  0.057640750670241284
# recall score on test dataset:  0.5657894736842105

# %%
X_C = dataAfterFE_avoid5914[col_list]
y_c = dataAfterFE_avoid5914[['ANN_AIR_FILTER_N']]

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_C)
accuracy_test_rf = accuracy_score(y_c,y_pred_rf_af_2)
precision_test_rf = precision_score(y_c, y_pred_rf_af_2)
recall_test_rf = recall_score(y_c, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[101989   7006]
#  [   131    630]]
# accuracy_score on test dataset :  0.9349739421990597
# precision score on test dataset:  0.08250392875851231
# recall score on test dataset:  0.8278580814717477

# %%
X_C_af_km = dataAfterFE_avoid5914.copy()
X_C_af_km['y_pred_af_rf2'] = y_pred_rf_af_2.ravel()
X_C_af_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
list(X_C_af_km.columns)
# Out:
# ['Power_mean',
#  'Power_median',
#  'Power_variance',
#  'Power_max',
#  'Power_min',
#  'Power_max-min',
#  'Power_kurtosis',
#  'Power_skewness',
#  'engine_speed_mean',
#  'engine_speed_median',
#  'engine_speed_variance',
#  'engine_speed_max',
#  'engine_speed_min',
#  'engine_speed_max-min',
#  'engine_speed_kurtosis',
#  'engine_speed_skewness',
#  'VEHICAL_BATTERY_POTENTIAL_mean',
#  'VEHICAL_BATTERY_POTENTIAL_median',
#  'VEHICAL_BATTERY_POTENTIAL_variance',
#  'VEHICAL_BATTERY_POTENTIAL_max',
#  'VEHICAL_BATTERY_POTENTIAL_min',
#  'VEHICAL_BATTERY_POTENTIAL_max-min',
#  'VEHICAL_BATTERY_POTENTIAL_kurtosis',
#  'VEHICAL_BATTERY_POTENTIAL_skewness',
#  'FUEL_CONSUM_mean',
#  'FUEL_CONSUM_median',
#  'FUEL_CONSUM_variance',
#  'FUEL_CONSUM_max',
#  'FUEL_CONSUM_min',
#  'FUEL_CONSUM_max-min',
#  'FUEL_CONSUM_kurtosis',
#  'FUEL_CONSUM_skewness',
#  'THROTTLE_POS_mean',
#  'THROTTLE_POS_median',
#  'THROTTLE_POS_variance',
#  'THROTTLE_POS_max',
#  'THROTTLE_POS_min',
#  'THROTTLE_POS_max-min',
#  'THROTTLE_POS_kurtosis',
#  'THROTTLE_POS_skewness',
#  'ACTUAL_ENGINE_TORQUE_mean',
#  'ACTUAL_ENGINE_TORQUE_median',
#  'ACTUAL_ENGINE_TORQUE_variance',
#  'ACTUAL_ENGINE_TORQUE_max',
#  'ACTUAL_ENGINE_TORQUE_min',
#  'ACTUAL_ENGINE_TORQUE_max-min',
#  'ACTUAL_ENGINE_TORQUE_kurtosis',
#  'ACTUAL_ENGINE_TORQUE_skewness',
#  'ENGINE_OIL_TEMP_mean',
#  'ENGINE_OIL_TEMP_median',
#  'ENGINE_OIL_TEMP_variance',
#  'ENGINE_OIL_TEMP_max',
#  'ENGINE_OIL_TEMP_min',
#  'ENGINE_OIL_TEMP_max-min',
#  'ENGINE_OIL_TEMP_kurtosis',
#  'ENGINE_OIL_TEMP_skewness',
#  'ENGINE_INTAKE_M_PRESSURE_mean',
#  'ENGINE_INTAKE_M_PRESSURE_median',
#  'ENGINE_INTAKE_M_PRESSURE_variance',
#  'ENGINE_INTAKE_M_PRESSURE_max',
#  'ENGINE_INTAKE_M_PRESSURE_min',
#  'ENGINE_INTAKE_M_PRESSURE_max-min',
#  'ENGINE_INTAKE_M_PRESSURE_kurtosis',
#  'ENGINE_INTAKE_M_PRESSURE_skewness',
#  'ENGINE_INTAKE_M_TEMPERATURE_mean',
#  'ENGINE_INTAKE_M_TEMPERATURE_median',
#  'ENGINE_INTAKE_M_TEMPERATURE_variance',
#  'ENGINE_INTAKE_M_TEMPERATURE_max',
#  'ENGINE_INTAKE_M_TEMPERATURE_min',
#  'ENGINE_INTAKE_M_TEMPERATURE_max-min',
#  'ENGINE_INTAKE_M_TEMPERATURE_kurtosis',
#  'ENGINE_INTAKE_M_TEMPERATURE_skewness',
#  'ENGINE_AIR_INLET_PRESSURE_mean',
#  'ENGINE_AIR_INLET_PRESSURE_median',
#  'ENGINE_AIR_INLET_PRESSURE_variance',
#  'ENGINE_AIR_INLET_PRESSURE_max',
#  'ENGINE_AIR_INLET_PRESSURE_min',
#  'ENGINE_AIR_INLET_PRESSURE_max-min',
#  'ENGINE_AIR_INLET_PRESSURE_kurtosis',
#  'ENGINE_AIR_INLET_PRESSURE_skewness',
#  'AMBIENT_AIR_TEMP_mean',
#  'AMBIENT_AIR_TEMP_median',
#  'AMBIENT_AIR_TEMP_variance',
#  'AMBIENT_AIR_TEMP_max',
#  'AMBIENT_AIR_TEMP_min',
#  'AMBIENT_AIR_TEMP_max-min',
#  'AMBIENT_AIR_TEMP_kurtosis',
#  'AMBIENT_AIR_TEMP_skewness',
#  'ENGINE_FUEL_TEMP_1_mean',
#  'ENGINE_FUEL_TEMP_1_median',
#  'ENGINE_FUEL_TEMP_1_variance',
#  'ENGINE_FUEL_TEMP_1_max',
#  'ENGINE_FUEL_TEMP_1_min',
#  'ENGINE_FUEL_TEMP_1_max-min',
#  'ENGINE_FUEL_TEMP_1_kurtosis',
#  'ENGINE_FUEL_TEMP_1_skewness',
#  'BAT_CHARGING_CURRENT_mean',
#  'BAT_CHARGING_CURRENT_median',
#  'BAT_CHARGING_CURRENT_variance',
#  'BAT_CHARGING_CURRENT_max',
#  'BAT_CHARGING_CURRENT_min',
#  'BAT_CHARGING_CURRENT_max-min',
#  'BAT_CHARGING_CURRENT_kurtosis',
#  'BAT_CHARGING_CURRENT_skewness',
#  'ENGINE_OIL_PRESSURE_mean',
#  'ENGINE_OIL_PRESSURE_median',
#  'ENGINE_OIL_PRESSURE_variance',
#  'ENGINE_OIL_PRESSURE_max',
#  'ENGINE_OIL_PRESSURE_min',
#  'ENGINE_OIL_PRESSURE_max-min',
#  'ENGINE_OIL_PRESSURE_kurtosis',
#  'ENGINE_OIL_PRESSURE_skewness',
#  'AIR_PRESSURE_1_mean',
#  'AIR_PRESSURE_1_median',
#  'AIR_PRESSURE_1_variance',
#  'AIR_PRESSURE_1_max',
#  'AIR_PRESSURE_1_min',
#  'AIR_PRESSURE_1_max-min',
#  'AIR_PRESSURE_1_kurtosis',
#  'AIR_PRESSURE_1_skewness',
#  'AIR_PRESSURE_2_mean',
#  'AIR_PRESSURE_2_median',
#  'AIR_PRESSURE_2_variance',
#  'AIR_PRESSURE_2_max',
#  'AIR_PRESSURE_2_min',
#  'AIR_PRESSURE_2_max-min',
#  'AIR_PRESSURE_2_kurtosis',
#  'AIR_PRESSURE_2_skewness',
#  'AIR_PRESSURE_DIGITAL_mean',
#  'AIR_PRESSURE_DIGITAL_median',
#  'AIR_PRESSURE_DIGITAL_variance',
#  'AIR_PRESSURE_DIGITAL_max',
#  'AIR_PRESSURE_DIGITAL_min',
#  'AIR_PRESSURE_DIGITAL_max-min',
#  'AIR_PRESSURE_DIGITAL_kurtosis',
#  'AIR_PRESSURE_DIGITAL_skewness',
#  'ENG_OIL_DIGITAL_mean',
#  'ENG_OIL_DIGITAL_median',
#  'ENG_OIL_DIGITAL_variance',
#  'ENG_OIL_DIGITAL_max',
#  'ENG_OIL_DIGITAL_min',
#  'ENG_OIL_DIGITAL_max-min',
#  'ENG_OIL_DIGITAL_kurtosis',
#  'ENG_OIL_DIGITAL_skewness',
#  'eng_coolant_temp_mean',
#  'eng_coolant_temp_median',
#  'eng_coolant_temp_variance',
#  'eng_coolant_temp_max',
#  'eng_coolant_temp_min',
#  'eng_coolant_temp_max-min',
#  'eng_coolant_temp_kurtosis',
#  'eng_coolant_temp_skewness',
#  'distance_idle%',
#  'distance_overrun%',
#  'distance_decel%',
#  'distance_accel%',
#  'time_idle%',
#  'time_overrun%',
#  'time_decel%',
#  'time_accel%',
#  '5409',
#  '535',
#  '525569',
#  '6912',
#  '5888',
#  '6144',
#  '131363',
#  '131619',
#  '8501',
#  '5688',
#  '262288',
#  '131895',
#  '4386',
#  '69888',
#  '5169',
#  '4356',
#  '4406',
#  '131906',
#  '267048',
#  'total',
#  '22',
#  '4377',
#  '408',
#  '267012',
#  '4390',
#  '9502',
#  '4369',
#  '1315',
#  '4371',
#  '65939',
#  '4613',
#  '1028',
#  '1025',
#  '1030',
#  '1156',
#  '4614',
#  '66104',
#  '1159',
#  '65816',
#  '275',
#  '1344',
#  '5376',
#  '1316',
#  '4374',
#  '66370',
#  '267024',
#  '537',
#  '663',
#  '9501',
#  '70434',
#  '267042',
#  '257',
#  '295',
#  '6657',
#  '131352',
#  '5120',
#  '6400',
#  '66359',
#  '1026',
#  '4626',
#  '1314',
#  '267060',
#  '4385',
#  '5696',
#  '4612',
#  '533',
#  '5634',
#  '4375',
#  '5159',
#  '74065',
#  'r_error',
#  'ANN_EGR_N',
#  'ANN_AIR_FILTER_N',
#  'vin',
#  'ANN_EGR_KM',
#  'ANN_AIR_FILTER_KM',
#  'y_pred_af_rf2',
#  'statedwell_km']

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_af_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_af_rf2']
        df3=df1[df1['ANN_AIR_FILTER_N']!=0][['ANN_AIR_FILTER_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_AIR_FILTER_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_af_km[X_C_af_km['ANN_AIR_FILTER_N']==1][['vin','ANN_AIR_FILTER_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_AIR_FILTER_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_knn_80.csv')

# %%
cm=[]
for ind,row in df_EGR_vinkm_formatted_compiled.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
42 / (42+1)
# Out:
# 0.9767441860465116

# %%
42 / (42+305)
# Out:
# 0.12103746397694524

# %%
(752+42) / 1122
# Out:
# 0.7076648841354723

# %%
12,300,40

# %% [markdown]
# ### RF Tuned 2

# %%
# Random Forest tuned
from sklearn.ensemble import RandomForestClassifier
random_forest_af_2 = RandomForestClassifier(n_estimators = 90, max_features = 'log2', max_depth = 14, min_samples_split = 300, class_weight={0:0.40,1:75})
random_forest_af_2.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_af_2.score(X_train, y_train)*100))
random_forest_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# '96.01'

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve,roc_auc_score

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf_af_2)
precision_test_rf = precision_score(y_test, y_pred_rf_af_2)
recall_test_rf = recall_score(y_test, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[31397  1329]
#  [  114   114]]
# accuracy_score on test dataset :  0.9562116890210597
# precision score on test dataset:  0.079002079002079
# recall score on test dataset:  0.5

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_C)
accuracy_test_rf = accuracy_score(y_c,y_pred_rf_af_2)
precision_test_rf = precision_score(y_c, y_pred_rf_af_2)
recall_test_rf = recall_score(y_c, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[104617   4378]
#  [   131    630]]
# accuracy_score on test dataset :  0.9589179634826343
# precision score on test dataset:  0.12579872204472844
# recall score on test dataset:  0.8278580814717477

# %%
X_C_af_km = dataAfterFE_avoid5914.copy()
X_C_af_km['y_pred_af_rf2'] = y_pred_rf_af_2.ravel()
X_C_af_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_af_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_af_rf2']
        df3=df1[df1['ANN_AIR_FILTER_N']!=0][['ANN_AIR_FILTER_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_AIR_FILTER_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_af_km[X_C_af_km['ANN_AIR_FILTER_N']==1][['vin','ANN_AIR_FILTER_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_AIR_FILTER_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']

# %%
cm=[]
for ind,row in df_EGR_vinkm_formatted_compiled.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
from collections import Counter
Counter(cm)
# Out:
# Counter({'TP': 43, 'FP': 185, 'TN': 894})

# %%
df_EGR_vinkm_formatted_compiled.to_csv('AirFilter_RFTuned2.csv')

# %%
import joblib
joblib.dump(random_forest_af_2,'AirFilter_RFTuned2.pkl')
# Out:
# ['AirFilter_RFTuned2.pkl']

# %% [markdown]
# ### RF Tuned 3

# %%
# Random Forest tuned
from sklearn.ensemble import RandomForestClassifier
random_forest_af_2 = RandomForestClassifier(n_estimators = 90, max_features = 'log2', max_depth = 12, min_samples_split = 350, class_weight={0:0.6,1:50})
random_forest_af_2.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_af_2.score(X_train, y_train)*100))
random_forest_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# '97.58'

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve,roc_auc_score

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf_af_2)
precision_test_rf = precision_score(y_test, y_pred_rf_af_2)
recall_test_rf = recall_score(y_test, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[31949   777]
#  [  141    87]]
# accuracy_score on test dataset :  0.9721429871942708
# precision score on test dataset:  0.10069444444444445
# recall score on test dataset:  0.3815789473684211

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_C)
accuracy_test_rf = accuracy_score(y_c,y_pred_rf_af_2)
precision_test_rf = precision_score(y_c, y_pred_rf_af_2)
recall_test_rf = recall_score(y_c, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[106474   2521]
#  [   259    502]]
# accuracy_score on test dataset :  0.9746710885965232
# precision score on test dataset:  0.1660602050942772
# recall score on test dataset:  0.6596583442838371

# %%
X_C_af_km = dataAfterFE_avoid5914.copy()
X_C_af_km['y_pred_af_rf2'] = y_pred_rf_af_2.ravel()
X_C_af_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_af_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_af_rf2']
        df3=df1[df1['ANN_AIR_FILTER_N']!=0][['ANN_AIR_FILTER_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_AIR_FILTER_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_af_km[X_C_af_km['ANN_AIR_FILTER_N']==1][['vin','ANN_AIR_FILTER_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_AIR_FILTER_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']

# %%
cm=[]
for ind,row in df_EGR_vinkm_formatted_compiled.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
from collections import Counter
Counter(cm)
# Out:
# Counter({'TP': 42, 'FP': 71, 'TN': 1008, 'FN': 1})

# %%
df_EGR_vinkm_formatted_compiled.to_csv('AirFilter_RFTuned3.csv')

# %%
joblib.dump(random_forest_af_2,'AirFilter_RFTuned3.pkl')
# Out:
# ['AirFilter_RFTuned3.pkl']

# %% [markdown]
# ### RF Tuned 4

# %%
# Random Forest tuned
from sklearn.ensemble import RandomForestClassifier
random_forest_af_2 = RandomForestClassifier(n_estimators = 90, max_features = 'auto', max_depth = 12, min_samples_split = 600, class_weight={0:0.6,1:35})
random_forest_af_2.fit(X_train, y_train)
#y_pred = random_forest.predict(X_test)
random_forest_score = ('{:.2f}'.format(random_forest_af_2.score(X_train, y_train)*100))
random_forest_score
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# '97.54'

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve,roc_auc_score

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_test)
accuracy_test_rf = accuracy_score(y_test,y_pred_rf_af_2)
precision_test_rf = precision_score(y_test, y_pred_rf_af_2)
recall_test_rf = recall_score(y_test, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[31964   762]
#  [  156    72]]
# accuracy_score on test dataset :  0.9721429871942708
# precision score on test dataset:  0.08633093525179857
# recall score on test dataset:  0.3157894736842105

# %%
y_pred_rf_af_2 = random_forest_af_2.predict(X_C)
accuracy_test_rf = accuracy_score(y_c,y_pred_rf_af_2)
precision_test_rf = precision_score(y_c, y_pred_rf_af_2)
recall_test_rf = recall_score(y_c, y_pred_rf_af_2)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred_rf_af_2,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[106548   2447]
#  [   359    402]]
# accuracy_score on test dataset :  0.9744341994970662
# precision score on test dataset:  0.14110214110214112
# recall score on test dataset:  0.5282522996057819

# %%
X_C_af_km = dataAfterFE_avoid5914.copy()
X_C_af_km['y_pred_af_rf2'] = y_pred_rf_af_2.ravel()
X_C_af_km['statedwell_km'] = dataAfterFE_withkm_avoid5914['statedwell_km'].values

# %%
#X_extended =pd.read_csv("AI_03_EGR_dataAfterFE_withkm.csv")
ls_TN=list()
ls_TP=list()
ls_FP=list()
ls_FN=list()

TN_Note_vin=list()
TN_Note_km=list()

FN_Note_vin=list()
FN_Note_km=list()

TP_Note_vin=list()
TP_Note_km=list()

FP_Note_vin=list()
FP_Note_km=list()

    
# veh count
points=0
flen=0
fc=0
TN=0
TP=0
FP=0
FN=0

df21 = X_C_af_km.groupby('vin')
OT = 1
for i in df21: # X_train_list
    df1=i[1]   
    if(len(df1)>0): 
        df2=pd.DataFrame()
        df2['y_pred']=df1['y_pred_af_rf2']
        df3=df1[df1['ANN_AIR_FILTER_N']!=0][['ANN_AIR_FILTER_KM']] # 0
        df3['Measurement in KM'] = df3['ANN_AIR_FILTER_KM']

        if(len(df3)==0):
            if(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                TN+=1
                TN_Note_vin.append(i[0])
                TN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            else:
                FP+=1
                FP_Note_vin.append(i[0])
                FP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
        else: 
            if((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].min()) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].min() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )
            
            elif((df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() <= df3['Measurement in KM'].max() ) & (df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].max()+25000 >= df3['Measurement in KM'].max() )): 
                TP+=1
                TP_Note_vin.append(i[0])
                TP_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min()) 
            
            elif(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].shape[0]==0): 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )                    
            
            else: 
                FN+=1
                FN_Note_vin.append(i[0])
                FN_Note_km.append(df1.loc[(df2[df2['y_pred']==OT]['y_pred']).index]['statedwell_km'].min() )

        #print(vin)
        #flen=flen+(len(df3['Measurement in KM'].unique()))
fc=fc+1
ls_TN.append(TN)
ls_TP.append(TP)
ls_FP.append(FP)
ls_FN.append(FN)

df_EGR_vinkm_TN = pd.DataFrame({'vin':TN_Note_vin, '1st_prediction_instance_km':TN_Note_km})
df_EGR_vinkm_TN['Predicted as Failed'] = "N"
df_EGR_vinkm_TN['Actual Failed'] = "N"

df_EGR_vinkm_TP = pd.DataFrame({'vin':TP_Note_vin, '1st_prediction_instance_km':TP_Note_km})
df_EGR_vinkm_TP['Predicted as Failed'] = "Y"
df_EGR_vinkm_TP['Actual Failed'] = "Y"

df_EGR_vinkm_FN = pd.DataFrame({'vin':FN_Note_vin, '1st_prediction_instance_km':FN_Note_km})
df_EGR_vinkm_FN['Predicted as Failed'] = "N"
df_EGR_vinkm_FN['Actual Failed'] = "Y"

df_EGR_vinkm_FP = pd.DataFrame({'vin':FP_Note_vin, '1st_prediction_instance_km':FP_Note_km})
df_EGR_vinkm_FP['Predicted as Failed'] = "Y"
df_EGR_vinkm_FP['Actual Failed'] = "N"

df_EGR_vinkm_formatted_compiled = pd.concat([df_EGR_vinkm_TP, df_EGR_vinkm_FP, df_EGR_vinkm_TN,df_EGR_vinkm_FN])
#df_EGR_vinkm_formatted_compiled.to_csv('D:/EGR_Failure_Prediction_formatted_compiled_svm.csv')

# %%
#df_EGR_vinkm = pd.DataFrame({'vin':Note_vin, 'km':Note_km})
df_failed = X_C_af_km[X_C_af_km['ANN_AIR_FILTER_N']==1][['vin','ANN_AIR_FILTER_KM']].drop_duplicates()
df_EGR_vinkm_formatted_compiled = df_EGR_vinkm_formatted_compiled.merge(df_failed, on='vin', how='outer')
df_EGR_vinkm_formatted_compiled['Predicted in advance km'] = df_EGR_vinkm_formatted_compiled['ANN_AIR_FILTER_KM']-df_EGR_vinkm_formatted_compiled['1st_prediction_instance_km']

# %%
cm=[]
for ind,row in df_EGR_vinkm_formatted_compiled.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
from collections import Counter
Counter(cm)
# Out:
# Counter({'TP': 38, 'FP': 70, 'TN': 1009, 'FN': 5})

# %%
df_EGR_vinkm_formatted_compiled.to_csv('AirFilter_RFTuned4.csv')

# %%
joblib.dump(random_forest_af_2,'AirFilter_RFTuned4.pkl')
# Out:
# ['AirFilter_RFTuned4.pkl']

# %% [markdown]
# # SVM FOR AIR FILTER

# %% [markdown]
# ### SVM using tuned hyper parameter values

# %%
#using kernel approximation - nystroem
from sklearn import svm
from sklearn.kernel_approximation import Nystroem
data = X_train #/ 16.
clf = svm.LinearSVC(class_weight={0:0.35,1:75}, dual = False, C = 0.8)
feature_map_nystroem = Nystroem(gamma=.5,
                                 random_state=1,
                                 n_components=500)
data_transformed = feature_map_nystroem.fit_transform(data)
clf.fit(data_transformed, y_train)
clf.score(data_transformed, y_train)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6176405561118986

# %%
data_test = X_test #/16
data_transformed_test = feature_map_nystroem.fit_transform(data_test)
y_pred = clf.predict(data_transformed_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve
accuracy_test_rf = accuracy_score(y_test,y_pred)
precision_test_rf = precision_score(y_test, y_pred)
recall_test_rf = recall_score(y_test, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[18241 14485]
#  [  110   118]]
# accuracy_score on test dataset :  0.5571099107847303
# precision score on test dataset:  0.008080531397658016
# recall score on test dataset:  0.5175438596491229

# %%
data_test = X_C #/16
data_transformed_test = feature_map_nystroem.fit_transform(data_test)
y_pred = clf.predict(data_transformed_test)

# %%
accuracy_test_rf = accuracy_score(y_c,y_pred)
precision_test_rf = precision_score(y_c, y_pred)
recall_test_rf = recall_score(y_c, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_c, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[75661 33334]
#  [  395   366]]
# accuracy_score on test dataset :  0.6926910601698313
# precision score on test dataset:  0.01086053412462908
# recall score on test dataset:  0.480946123521682

# %% [markdown]
# ### SVM using higher hyperparameter values

# %%
#using kernel approximation - nystroem
from sklearn import svm
from sklearn.kernel_approximation import Nystroem
data = X_train #/ 16.
clf = svm.LinearSVC(class_weight={0:0.3,1:75},dual = False, C = 2*5)# 
feature_map_nystroem = Nystroem(kernel = 'rbf', gamma=2**6,
                                 random_state=1,
                                 n_components=500, degree = 5)
data_transformed = feature_map_nystroem.fit_transform(data)
clf.fit(data_transformed, y_train)
clf.score(data_transformed, y_train)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6283050031863286

# %%
data_test = X_test #/16
data_transformed_test = feature_map_nystroem.fit_transform(data_test)
y_pred = clf.predict(data_transformed_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,roc_curve
accuracy_test_rf = accuracy_score(y_test,y_pred)
precision_test_rf = precision_score(y_test, y_pred)
recall_test_rf = recall_score(y_test, y_pred)
    
print('rf confusion matrix : ',confusion_matrix(y_test, y_pred,labels=[0,1]))
print('accuracy_score on test dataset : ', accuracy_test_rf)
print('precision score on test dataset: ',precision_test_rf)
print('recall score on test dataset: ',recall_test_rf)
# Out:
# rf confusion matrix :  [[22918  9808]
#  [  133    95]]
# accuracy_score on test dataset :  0.6983370759240153
# precision score on test dataset:  0.009593052610320105
# recall score on test dataset:  0.4166666666666667

# %%
# from sklearn.svm import SVC
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import StratifiedShuffleSplit
# C_range = np.logspace(-2, 10, 13)
# gamma_range = np.logspace(-9, 3, 13)
# param_grid = dict(gamma=gamma_range, C=C_range)
# cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
# grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv)
# grid.fit(X_train, y_train)

# %%
test = pd.read_csv('AirFilter_RFTuned3.csv')

# %%
cm=[]
for ind,row in test.iterrows():
    if row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('TP')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'N':
        cm.append('TN')
    elif row.loc['Actual Failed'] == 'Y' and row.loc['Predicted as Failed'] == 'N':
        cm.append('FN')
    elif row.loc['Actual Failed'] == 'N' and row.loc['Predicted as Failed'] == 'Y':
        cm.append('FP')

# %%
Counter(cm)
# Out:
# Counter({'TP': 42, 'FP': 71, 'TN': 1008, 'FN': 1})
